# %%
# to download osm data
import osmnx as ox

# to import and explore data
import pandas as pd

# to manipulate and visualize spatial data
import geopandas as gpd

# to provide basemaps 
import contextily as ctx

# %%
address = 'India,Maharashtra,Mumbai,Matunga'

# %%
# get the data from OSM that are tagged as 'building' for a 1000m X 1000m square area
osm = ox.geometries_from_address(address,tags={'building':True},dist=1000)

# %%
# how many rows and columns?
osm.shape
# Out:
# (1944, 53)

# %%
# what is the datatype?
type(osm)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# what are the columns and their datatypes?
osm.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# MultiIndex: 1944 entries, ('node', 5057814507) to ('relation', 9302735)
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   building                  1944 non-null   object
#  1   name                      400 non-null    object
#  2   geometry                  1944 non-null   geometry
#  3   nodes                     1943 non-null   object
#  4   addr:city                 495 non-null    object
#  5   addr:housenumber          271 non-null    object
#  6   addr:postcode             187 non-null    object
#  7   addr:street               191 non-null    object
#  8   club                      1 non-null      object
#  9   designation               1 non-null      object
#  10  sport                     1 non-null      object
#  11  amenity                   40 non-null     object
#  12  religion                  11 non-null     object
#  13  historic                  1 non-null      object
#  14  building:flats            1 non-null      object
#  15  building:levels           28 non-null     object
#  16  layer                     3 non-null      object
#  17  architect                 1 non-null      object
#  18  addr:full                 1 non-null      object
#  19  addr:state                1 non-null      object
#  20  healthcare:speciality     1 non-null      object
#  21  source                    2 non-null      object
#  22  name:en                   2 non-null      object
#  23  fee                       6 non-null      object
#  24  isced:level               5 non-null      object
#  25  website                   5 non-null      object
#  26  building:use              1 non-null      object
#  27  old_name                  1 non-null      object
#  28  addr:housename            2 non-null      object
#  29  alt_name                  4 non-null      object
#  30  shop                      5 non-null      object
#  31  landuse                   1 non-null      object
#  32  brand                     1 non-null      object
#  33  brand:wikidata            1 non-null      object
#  34  brand:wikipedia           1 non-null      object
#  35  short_name                1 non-null      object
#  36  email                     1 non-null      object
#  37  payment:american_express  1 non-null      object
#  38  payment:cash              1 non-null      object
#  39  payment:cheque            1 non-null      object
#  40  payment:credit_cards      1 non-null      object
#  41  payment:debit_cards       1 non-null      object
#  42  payment:mastercard        1 non-null      object
#  43  payment:visa              1 non-null      object
#  44  payment:visa_debit        1 non-null      object
#  45  phone                     2 non-null      object
#  46  tourism                   1 non-null      object
#  47  description               1 non-null      object
#  48  height                    3 non-null      object
#  49  railway                   8 non-null      object
#  50  addr:suburb               1 non-null      object
#  51  ways                      8 non-null      object
#  52  type                      8 non-null      object
# dtypes: geometry(1), object(52)
# memory usage: 890.6+ KB

# %%
# show me the first 5 rows
osm.head()
# Out:
#                         building                         name  \
# element_type osmid
# node         5057814507      yes           Mysore Association
# way          49684327        yes  Dadar Parsi Colony Gymkhana
#              112781800    church             Don Bosco Church
#              112785300    school                          NaN
#              113566048       yes                Empress Mahal
#
#                                                                   geometry  \
# element_type osmid
# node         5057814507                          POINT (72.85489 19.02836)
# way          49684327    POLYGON ((72.85078 19.02139, 72.85015 19.02058...
#              112781800   POLYGON ((72.85720 19.02583, 72.85722 19.02568...
#              112785300   POLYGON ((72.85583 19.03256, 72.85598 19.03274...
#              113566048   POLYGON ((72.84724 19.01831, 72.84740 19.01821...
#
#                                                                      nodes  \
# element_type osmid
# node         5057814507                                                NaN
# way          49684327    [631525353, 631525355, 631525357, 631525359, 6...
#              112781800   [1281204623, 1281204610, 1281204591, 128120462...
#              112785300   [1281234581, 1281234576, 1281234582, 128123458...
#              113566048   [1287692267, 1287692149, 1287692263, 128769220...
#
#                         addr:city addr:housenumber addr:postcode  \
# element_type osmid
# node         5057814507       NaN              NaN           NaN
# way          49684327      Mumbai          605-606        400014
#              112781800        NaN              NaN           NaN
#              112785300        NaN              NaN           NaN
#              113566048     Mumbai              170        400014
#
#                                                        addr:street   club  \
# element_type osmid
# node         5057814507                                        NaN    NaN
# way          49684327    Dr Babasaheb Ambedkar Marg (Vincent Road)  sport
#              112781800                                         NaN    NaN
#              112785300                                         NaN    NaN
#              113566048                             Khodadad Circle    NaN
#
#                                    designation  ... payment:visa  \
# element_type osmid                              ...
# node         5057814507                    NaN  ...          NaN
# way          49684327    Dadar Parsee Gymkhana  ...          NaN
#              112781800                     NaN  ...          NaN
#              112785300                     NaN  ...          NaN
#              113566048                     NaN  ...          NaN
#
#                         payment:visa_debit phone tourism description height  \
# element_type osmid
# node         5057814507                NaN   NaN     NaN         NaN    NaN
# way          49684327                  NaN   NaN     NaN         NaN    NaN
#              112781800                 NaN   NaN     NaN         NaN    NaN
#              112785300                 NaN   NaN     NaN         NaN    NaN
#              113566048                 NaN   NaN     NaN         NaN    NaN
#
#                         railway addr:suburb ways type
# element_type osmid
# node         5057814507     NaN         NaN  NaN  NaN
# way          49684327       NaN         NaN  NaN  NaN
#              112781800      NaN         NaN  NaN  NaN
#              112785300      NaN         NaN  NaN  NaN
#              113566048      NaN         NaN  NaN  NaN
#
# [5 rows x 53 columns]

# %%
# show me 10 random rows
osm.sample(10)
# Out:
#                            building   name  \
# element_type osmid
# way          116342809          yes    NaN
#              434908123          yes    NaN
#              357187607          yes    NaN
#              357187378          yes    NaN
#              115839995          yes    NaN
#              357360160          yes    NaN
#              357112712          yes    NaN
#              356529191   apartments    NaN
#              113717548  residential    NaN
#              116342783          yes  Sador
#
#                                                                  geometry  \
# element_type osmid
# way          116342809  POLYGON ((72.85847 19.02230, 72.85847 19.02190...
#              434908123  POLYGON ((72.84916 19.03038, 72.84992 19.03145...
#              357187607  POLYGON ((72.85169 19.03500, 72.85181 19.03523...
#              357187378  POLYGON ((72.84842 19.03233, 72.84849 19.03232...
#              115839995  POLYGON ((72.85375 19.02657, 72.85386 19.02648...
#              357360160  POLYGON ((72.84170 19.02912, 72.84186 19.02909...
#              357112712  POLYGON ((72.85915 19.03439, 72.85929 19.03433...
#              356529191  POLYGON ((72.84636 19.03589, 72.84665 19.03593...
#              113717548  POLYGON ((72.84799 19.01981, 72.84814 19.01972...
#              116342783  POLYGON ((72.85865 19.02137, 72.85862 19.02119...
#
#                                                                     nodes  \
# element_type osmid
# way          116342809  [1311768696, 1311768834, 1311768705, 131176871...
#              434908123  [4328189086, 4328189119, 9146962962, 914696296...
#              357187607  [3625173201, 3625173245, 3625173241, 362517321...
#              357187378  [3625169263, 3625169262, 3625169260, 362516926...
#              115839995  [1307618471, 1307618469, 1307618515, 130761850...
#              357360160  [3626442697, 3626442694, 3626442682, 362644268...
#              357112712  [3624740524, 3624740522, 3624740510, 362474051...
#              356529191  [3619436957, 3619436970, 3619436941, 361943692...
#              113717548  [1289170448, 1289170277, 1289170450, 128917038...
#              116342783  [1311768803, 1311768786, 1311768807, 131176872...
#
#                              addr:city addr:housenumber addr:postcode  \
# element_type osmid
# way          116342809             NaN              NaN           NaN
#              434908123             NaN              NaN           NaN
#              357187607             NaN              NaN           NaN
#              357187378             NaN              NaN           NaN
#              115839995             NaN              NaN           NaN
#              357360160             NaN              NaN           NaN
#              357112712             NaN              NaN           NaN
#              356529191          Mumbai              NaN           NaN
#              113717548             NaN             176A           NaN
#              116342783  Wadala, Mumbai      Plot No 151        400031
#
#                                       addr:street club designation  ...  \
# element_type osmid                                                  ...
# way          116342809                        NaN  NaN         NaN  ...
#              434908123                        NaN  NaN         NaN  ...
#              357187607                        NaN  NaN         NaN  ...
#              357187378                        NaN  NaN         NaN  ...
#              115839995                        NaN  NaN         NaN  ...
#              357360160                        NaN  NaN         NaN  ...
#              357112712                        NaN  NaN         NaN  ...
#              356529191                        NaN  NaN         NaN  ...
#              113717548                        NaN  NaN         NaN  ...
#              116342783  Major R Parameswaran Road  NaN         NaN  ...
#
#                        payment:visa payment:visa_debit phone tourism  \
# element_type osmid
# way          116342809          NaN                NaN   NaN     NaN
#              434908123          NaN                NaN   NaN     NaN
#              357187607          NaN                NaN   NaN     NaN
#              357187378          NaN                NaN   NaN     NaN
#              115839995          NaN                NaN   NaN     NaN
#              357360160          NaN                NaN   NaN     NaN
#              357112712          NaN                NaN   NaN     NaN
#              356529191          NaN                NaN   NaN     NaN
#              113717548          NaN                NaN   NaN     NaN
#              116342783          NaN                NaN   NaN     NaN
#
#                        description height   railway addr:suburb ways type
# element_type osmid
# way          116342809         NaN    NaN       NaN         NaN  NaN  NaN
#              434908123         NaN    NaN  workshop         NaN  NaN  NaN
#              357187607         NaN    NaN       NaN         NaN  NaN  NaN
#              357187378         NaN    NaN       NaN         NaN  NaN  NaN
#              115839995         NaN    NaN       NaN         NaN  NaN  NaN
#              357360160         NaN    NaN       NaN         NaN  NaN  NaN
#              357112712         NaN    NaN       NaN         NaN  NaN  NaN
#              356529191         NaN    NaN       NaN         NaN  NaN  NaN
#              113717548         NaN    NaN       NaN         NaN  NaN  NaN
#              116342783         NaN    NaN       NaN         NaN  NaN  NaN
#
# [10 rows x 53 columns]

# %%
# subset it

# create a list of column names you want to keep
columns_to_keep = ['geometry','building']

# redefine the dataframe based on only the columns we want to keep 
osm = osm[columns_to_keep]

# output 10 random rows
osm.sample(10)
# Out:
#                                                                  geometry  \
# element_type osmid
# way          119209019  POLYGON ((72.85057 19.02401, 72.85053 19.02388...
#              116342791  POLYGON ((72.85761 19.02206, 72.85760 19.02193...
#              357082801  POLYGON ((72.85862 19.02904, 72.85850 19.02912...
#              685548839  POLYGON ((72.84857 19.02212, 72.84888 19.02192...
#              113693390  POLYGON ((72.84934 19.01937, 72.84947 19.01929...
#              358851639  POLYGON ((72.85593 19.02015, 72.85602 19.02012...
#              136169126  POLYGON ((72.84427 19.02889, 72.84448 19.02884...
#              356550741  POLYGON ((72.84706 19.01946, 72.84713 19.01955...
#              136169128  POLYGON ((72.84412 19.02864, 72.84440 19.02857...
#              119209038  POLYGON ((72.85120 19.02446, 72.85130 19.02438...
#
#                            building
# element_type osmid
# way          119209019  residential
#              116342791          yes
#              357082801          yes
#              685548839          yes
#              113693390  residential
#              358851639          yes
#              136169126          yes
#              356550741          yes
#              136169128          yes
#              119209038          yes

# %%
# assign a new variable for building counts
osm_building_counts = osm.building.value_counts()

# output the results
osm_building_counts
# Out:
# building
# yes              1434
# apartments        259
# residential       191
# school             21
# college            20
# commercial          9
# church              2
# bungalow            2
# train_station       2
# public              1
# retail              1
# mosque              1
# house               1
# Name: count, dtype: int64

# %%
type(osm_building_counts)
# Out:
# pandas.core.series.Series

# %%
# create a new variable and convert it into a pandas dataframe
df_osm_building_types = pd.DataFrame(osm_building_counts)

# what does the dataframe look like?
df_osm_building_types
# Out:
#                count
# building
# yes             1434
# apartments       259
# residential      191
# school            21
# college           20
# commercial         9
# church             2
# bungalow           2
# train_station      2
# public             1
# retail             1
# mosque             1
# house              1

# %%
# reset the index
df_osm_building_types = df_osm_building_types.reset_index()
df_osm_building_types
# Out:
#          building  count
# 0             yes   1434
# 1      apartments    259
# 2     residential    191
# 3          school     21
# 4         college     20
# 5      commercial      9
# 6          church      2
# 7        bungalow      2
# 8   train_station      2
# 9          public      1
# 10         retail      1
# 11         mosque      1
# 12          house      1

# %%
df_osm_building_types.columns = ['building_type','count']
df_osm_building_types
# Out:
#     building_type  count
# 0             yes   1434
# 1      apartments    259
# 2     residential    191
# 3          school     21
# 4         college     20
# 5      commercial      9
# 6          church      2
# 7        bungalow      2
# 8   train_station      2
# 9          public      1
# 10         retail      1
# 11         mosque      1
# 12          house      1

# %%
df_osm_building_types.plot()
# Out:
# <AxesSubplot:>

# %%
df_osm_building_types.plot.barh(figsize=(12,6),
                                x='building_type')
# Out:
# <AxesSubplot:ylabel='building_type'>

# %%
# sort it the other way
df_osm_building_types = df_osm_building_types.sort_values(by='count', ascending=True)
df_osm_building_types
# Out:
#     building_type  count
# 9          public      1
# 10         retail      1
# 11         mosque      1
# 12          house      1
# 6          church      2
# 7        bungalow      2
# 8   train_station      2
# 5      commercial      9
# 4         college     20
# 3          school     21
# 2     residential    191
# 1      apartments    259
# 0             yes   1434

# %%
df_osm_building_types[-10:].plot.barh(figsize=(12,4),
                                      x='building_type',
                                      y='count',
                                      title="Top 10 building types in "+address)
# Out:
# <AxesSubplot:title={'center':'Top 10 building types in India,Maharashtra,Mumbai,Matunga'}, ylabel='building_type'>

# %%
# check the data type
type(osm)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# plot entire dataset
ax = osm.plot(figsize=(10,10))

# %%
# plot a single random building
ax = osm.sample(1).plot()

# %%
# create the map plot
ax = osm.plot(figsize=(10,10),
         column='building',
         cmap='tab20',
         legend=True,
         legend_kwds={'loc':'upper left','bbox_to_anchor':(1,1),'frameon':False})

# additional attributes to the map plot

# add a title
ax.set_title('Building types in ' + address)

# get rid of the axis
ax.axis('off')
# Out:
# (72.839276015, 72.86153088500001, 19.017178004999998, 19.037875495)

# %%
# reproject to Web Mercator
osm_web_mercator = osm.to_crs(epsg=3857)

# %%
# add the basemap

# %%
ax = osm_web_mercator.plot(figsize=(10,10),
                            column='building',
                            cmap='tab20',
                            legend=True,
                            legend_kwds={'loc':'upper left','bbox_to_anchor':(1,1),'frameon':False})


# add a title
ax.set_title('Building types in ' + address)

# basemap from carto that has a dark background (easier to see)
ctx.add_basemap(ax,source=ctx.providers.CartoDB.DarkMatter)

# %%
ax = osm_web_mercator.plot(figsize=(10,10),
                            column='building',
                            cmap='tab20',
                            legend=True,
                            legend_kwds={'loc':'upper left','bbox_to_anchor':(1,1),'frameon':False})


# add a title
ax.set_title('Building types in ' + address)

# open street map basemap
ctx.add_basemap(ax,source=ctx.providers.OpenStreetMap.Mapnik)

# %%
# import matplotlib's colors library
import matplotlib.colors as colors

# create a list of colors based on the number of items in your legend (14), and in this case, make it all grays
color_ramp = ['gainsboro']*14

# assign a single value in the list to be red. In this case, the 3rd entry in the list is for "commercial" buildings.
color_ramp[2] = 'red'

# create your colormap 
custom_cmap = colors.ListedColormap(color_ramp)

# %%
ax = osm.plot(figsize=(10,10),
         column='building',
         cmap=custom_cmap,
         legend=True,
         legend_kwds={'loc':'upper left','bbox_to_anchor':(1,1),'frameon':False})

# add a title
ax.set_title('Building types in ' + address)

# get rid of the axis
ax.axis('off')
# Out:
# (72.839276015, 72.86153088500001, 19.017178004999998, 19.037875495)

# %%
# here is the function
def make_building_map(location):
    # get the data from osm
    osm = ox.geometries_from_address(location,
                                     tags={'building':True},
                                     dist=1000)
    
    # reproject to Web Mercator
    osm_web_mercator = osm.to_crs(epsg=3857)
    
    # create the map
    ax = osm_web_mercator.plot(figsize=(10,10),
                                column='building',
                                cmap='tab20',
                                legend=True,
                                legend_kwds={'loc':'upper left','bbox_to_anchor':(1,1),'frameon':False})
    
    # additional features

    # add a title
    ax.set_title('Building types in ' + location)

    # get rid of the axis
    ax.axis('off')
    
    # add a dark basemap
    ctx.add_basemap(ax,source=ctx.providers.CartoDB.DarkMatter)

# %%
# %%time
# run the function once
make_building_map(address)
# Out:
# CPU times: total: 781 ms
# Wall time: 1.02 s

# %%
address_list = [address]

# %%
# %%time
# run our function for every address in our list
for add in address_list:
    make_building_map(add)
# Out:
# CPU times: total: 844 ms
# Wall time: 942 ms
